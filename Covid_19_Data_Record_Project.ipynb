# %% [markdown]
# <a href="https://colab.research.google.com/github/unstoabble-mj/Covid_19/blob/main/Covid_19_Data_Record_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Covid 19 Dataset**

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63c212e6-d7f6-4508-805c-4e1084e148a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63c212e6-d7f6-4508-805c-4e1084e148a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Covid_19_Dataset.csv')

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# **Q 1 ) Show the number of confirmed , Death & Recovered cases in each Region.**

# %%
data.groupby('Region')

# %%
data.groupby('Region').sum()
# Out:
#                          Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020     0       1939      60        252
# Albania             4/29/2020     0        766      30        455
# Algeria             4/29/2020     0       3848     444       1702
# Andorra             4/29/2020     0        743      42        423
# Angola              4/29/2020     0         27       2          7
# ...                       ...   ...        ...     ...        ...
# West Bank and Gaza  4/29/2020     0        344       2         71
# Western Sahara      4/29/2020     0          6       0          5
# Yemen               4/29/2020     0          6       0          1
# Zambia              4/29/2020     0         97       3         54
# Zimbabwe            4/29/2020     0         32       4          5
#
# [187 rows x 5 columns]

# %%
#Show just First 7 Record
data.groupby('Region').sum().head(7)
# Out:
#                           Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan          4/29/2020     0       1939      60        252
# Albania              4/29/2020     0        766      30        455
# Algeria              4/29/2020     0       3848     444       1702
# Andorra              4/29/2020     0        743      42        423
# Angola               4/29/2020     0         27       2          7
# Antigua and Barbuda  4/29/2020     0         24       3         11
# Argentina            4/29/2020     0       4285     214       1192

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# **Q 2) Remove all the records where Confirmed Cases is Less Than 10**

# %%
data=data[data.Confirmed <10 ]

# %%
data.Confirmed <10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %% [markdown]
# **Q 3) In which Region, Maximum number of Confirmed cases were Recorded ?**

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# **Q 4) In which Region, Minimum number of Deaths cases were Recorded ?**

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(20)
# Out:
# Region
# Cambodia                    0
# Bhutan                      0
# Dominica                    0
# Central African Republic    0
# Eritrea                     0
# Fiji                        0
# Holy See                    0
# Mozambique                  0
# Macau                       0
# Madagascar                  0
# Namibia                     0
# Mongolia                    0
# Nepal                       0
# Laos                        0
# Grenada                     0
# Papua New Guinea            0
# Sao Tome and Principe       0
# Seychelles                  0
# South Sudan                 0
# Uganda                      0
# Name: Deaths, dtype: int64

# %% [markdown]
# **Q 5) How many Confirmed , Deaths & Recovered cases were reported from India till 29 April 2020?**

# %%
data[data.Region=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# **Q 6) Sort the entire data wrt No. of Confirmed cases in ascending order.**

# %%
data.sort_values(by = ['Confirmed'], ascending =True).head(20)
# Out:
#           Date                             State                 Region  \
# 284  4/29/2020                         Recovered                 Canada
# 285  4/29/2020                         Recovered                     US
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 305  4/29/2020                             Tibet         Mainland China
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 272  4/29/2020             Northwest Territories                 Canada
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# 194  4/29/2020            British Virgin Islands                     UK
# 177  4/29/2020                               NaN         Western Sahara
# ...

# %% [markdown]
# **Q 7) Sort the entire data wrt  No. of Recovered cases in desending order.**

# %%
data.sort_values(by =['Recovered'],ascending=False).head(20)
# Out:
#           Date      State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020        NaN           Spain     236899   24275     132929
# 285  4/29/2020  Recovered              US          0       0     120720
# 61   4/29/2020        NaN         Germany     161539    6467     120400
# 76   4/29/2020        NaN            Iran      93657    5957      73791
# 80   4/29/2020        NaN           Italy     203591   27682      71252
# 229  4/29/2020      Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020        NaN          France     165093   24087      48228
# 167  4/29/2020        NaN          Turkey     117589    3081      44040
# 22   4/29/2020        NaN          Brazil      79685    5513      34132
# 158  4/29/2020        NaN     Switzerland      29407    1716      22600
# 284  4/29/2020  Recovered          Canada          0       0      20327
# 78   4/29/2020        NaN         Ireland      20253    1190      13386
# ...
